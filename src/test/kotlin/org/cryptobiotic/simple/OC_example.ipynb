// %%
%use kandy

// %%
import org.cryptobiotic.rla.*

val audit: AuditSimple = makeTestAudit(1000)

val manifest = DataFrame.read("/home/stormy/dev/github/rla/shangrla-kotlin/src/test/data/rla/OC_full_manifest.xlsx")
manifest.schema()
// Out:
// Batch Name: String
// Number of Ballots: Double
// Container: Double
// Tabulator: Double
// cum_cards: Double

// %%
val wtf = manifest["Number of Ballots"] as ValueColumn<Double>
wtf.toList().sum()
// Out:
// 3094308.0

// %%
val cvrs = DataFrame.read("/home/stormy/dev/github/rla/shangrla-kotlin/src/test/data/Hart/Hart_manifest.xlsx")
cvrs
// Out:
//             <iframe onload="o_resize_iframe_out_1()" style="width:100%;" class="result_container" id="iframe_out_1" frameBorder="0" srcdoc="        &lt;html theme='dark'&gt;
//         &lt;head&gt;
//             &lt;style type=&quot;text&sol;css&quot;&gt;
//                 :root {
//     --background: #fff;
//     --background-odd: #f5f5f5;
//     --background-hover: #d9edfd;
//     --header-text-color: #474747;
//     --text-color: #848484;
//     --text-color-dark: #000;
//     --text-color-medium: #737373;
//     --text-color-pale: #b3b3b3;
//     --inner-border-color: #aaa;
//     --bold-border-color: #000;
//     --link-color: #296eaa;
//     --link-color-pale: #296eaa;
//     --link-hover: #1a466c;
// }
//
// :root[theme=&quot;dark&quot;], :root [data-jp-theme-light=&quot;false&quot;], .dataframe_dark{
//     --background: #303030;
//     --background-odd: #3c3c3c;
//     --background-hover: #464646;
//     --header-text-color: #dddddd;
//     --text-color: #b3b3b3;
// ...

// %%
val cvrs : List<CvrSimple> = makeSimpleCvrs(100)
val votes: Map<String, Map<String, Int>> = CvrSimple.tabulate_votes(cvrs)
val styles: Map<Set<String>, Int> = CvrSimple.tabulate_styles(cvrs)
val cards: Map<String, Int> = CvrSimple.tabulate_cards_contests(cvrs)

val contests: List<ContestSimple> = ContestSimple.fromVotes(audit, votes, cards)

// fun make_plurality_assertions(contest: ContestSimple, winner: List<String>, loser: List<String>, test: TestFn? = null, estim: EstimatorFn? = null, bet: BetFn? = null): Map<String, AssertionSimple> {
val assertions = contests.map {
     make_plurality_assertions(it, listOf("A"), listOf("B"))
}
assertions
// Out:
// [{A v B=AssertionSimple(contest=ContestSimple(id=contest, name=contest, candidates=[A, B], choice_function=PLURALITY, assertions={}, assertion_file=null, audit_type=CARD_COMPARISON, betFn=null, estimFn=null, testFn=null, g=0.1, n_winners=1, reported_winners=[], risk_limit=0.05, ncvrs=0, ncards=100, sample_size=null, sample_threshold=null, share_to_win=0.5, tally={}, use_style=true), assorter=AssorterFn(contest=ContestSimple(id=contest, name=contest, candidates=[A, B], choice_function=PLURALITY, assertions={}, assertion_file=null, audit_type=CARD_COMPARISON, betFn=null, estimFn=null, testFn=null, g=0.1, n_winners=1, reported_winners=[], risk_limit=0.05, ncvrs=0, ncards=100, sample_size=null, sample_threshold=null, share_to_win=0.5, tally={}, use_style=true), upper_bound=1.0, assort=(org.cryptobiotic.shangrla.core.Cvr) -> kotlin.Double), winner=A, loser=B, test=org.cryptobiotic.shangrla.core.NonnegMean@64787d2e, margin=null, p_value=null, p_history=null, proved=false, sample_size=null
// ...
